# %%
import pandas as pd

# %%
quick_df = pd.read_csv("../fully_processed_data4.csv",
                      index_col = 0)
# Out:
# /Users/atakanokan/anaconda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:395: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.hist(quick_df["price"], bins=3000, width =50)
plt.xlim(0, 1000)
plt.title("Histogram of Prices")
plt.show()

# %%
plt.hist(quick_df["bathrooms"], bins=100, width =0.3)
plt.xlim(0, 5)
plt.title("Histogram of Bathrooms")
plt.show()

# %%
plt.hist(quick_df["bedrooms"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Bedrooms")
plt.show()

# %%
plt.hist(quick_df["accommodates"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Accommodates")
plt.show()

# %%
plt.hist(quick_df["review_scores_cleanliness"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Cleanliness Ratings")
plt.show()

# %%
plt.hist(quick_df["review_scores_location"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Location Ratings")
plt.show()

# %%
plt.hist(quick_df["review_scores_accuracy"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Description Accuracy Ratings")
plt.show()

# %%
plt.hist(quick_df["weekday"], bins=100, width =0.5)
plt.xlim(0, 11)
plt.title("Histogram of Weekday")
plt.show()

# %% [markdown]
# We have a near random sample from all the weekdays

# %%
plt.hist(quick_df["review_scores_rating"], bins=100, width =0.5)
plt.xlim(50, 101)
plt.title("Histogram of Ratings")
plt.show()

# %%
plt.hist(quick_df["year"], bins=100, width = 0.5)
plt.xlim(2015, 2020)
plt.title("Histogram of Years")
plt.show()

# %%
quick_df[quick_df["state: TX"] == True]["price"].mean()
# Out:
# 251.6797925838278

# %%
quick_df[quick_df["state: NC"] == True]["price"].mean()
# Out:
# 130.80498049804982

# %%
quick_df[quick_df["state: MA"] == True]["price"].mean()
# Out:
# 301.5256278910931

# %%
quick_df[quick_df["state: IL"] == True]["price"].mean()
# Out:
# 202.9880540889581

# %%
quick_df[quick_df["state: CO"] == True]["price"].mean()
# Out:
# 137.3038678046123

# %%
quick_df[quick_df["state: CA"] == True]["price"].mean()
# Out:
# 169.3251609543647

# %%
quick_df[quick_df["state: TN"] == True]["price"].mean()
# Out:
# 138.2806324110672

# %%
quick_df[quick_df["state: NY"] == True]["price"].mean()
# Out:
# 188.78222460718058
